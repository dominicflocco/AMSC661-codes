# %% [markdown]
# ### AMSC 661, Final Exam
# #### Problem 3, part (c)
# Author: Dominic Flocco
# Date: May 17, 2023

# %%
from distmesh import * 
import numpy as np 
import scipy as sc
from scipy.sparse import csr_matrix
from scipy.sparse import diags
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

plt.rcParams.update({
        "font.family": "Times", 
        "text.usetex": True,
        "font.size": 16
    })

# %% [markdown]
# Generates mesh on domain $\Omega = [-1,1]^2$.

# %%
h = 0.04 # mesh step

# Fixed Points 
pfix = np.array([[1,-1], [1,1], [-1,1], [-1,-1]])
bbox = np.array([-1,1,-1,1])

# Distance function 
def fd(p):
    return drectangle(p,-1,1,-1,1)
pts, tri = distmesh2D(fd, huniform, h, bbox, pfix)

# Save mesh to matlab workspace file
sc.io.savemat('mesh.mat', {'pts': pts, 'tri': tri})

# Plot mesh 
pts,tri = fixmesh(pts,tri)
plt.triplot(pts[:,0],pts[:,1],tri,linewidth=0.1)
axes=plt.gca()
axes.set_aspect(1)
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.title('Triangulated Mesh on Domain $\Omega = [-1,1]^2$')
# Out:
# count =  200 displacement =  0.012168586783411093
# count =  400 displacement =  0.0034232089969463554
# count =  600 displacement =  0.0037272056505444967
# count =  800 displacement =  0.003385927624387421
# count =  1000 displacement =  0.0026123859523727363
# count =  1200 displacement =  0.0023135995093220927

# %%
plt.triplot(pts[:,0],pts[:,1],tri,linewidth=0.1)
axes=plt.gca()
axes.set_aspect(1)
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.title('Triangulated Mesh on Domain $\Omega = [-1,1]^2$')
# Out:
# Text(0.5, 1.0, 'Triangulated Mesh on Domain $\\Omega = [-1,1]^2$')

# %%
print("Hi will!")
# Out:
# Hi will!
